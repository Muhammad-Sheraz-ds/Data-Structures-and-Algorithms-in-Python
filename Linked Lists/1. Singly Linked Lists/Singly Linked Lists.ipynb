# %% [markdown]
# # SinglyLinkedList Implementation

# %% [markdown]
# ## Introduction
# Provide a brief introduction to the purpose of this code and what the `MyLinkedList` class does.
#
# ## Class Structure
# Explain the class structure, its components, and their functionalities.
#
# ### Node
# - The `Node` class represents individual elements in the linked list.
# - It contains attributes for `value` and `next_node`.
#
# ### MyLinkedList
# - The main class, `MyLinkedList`, represents the linked list and includes methods for manipulation.
#
# ## Class Methods
# Describe each of the class methods and their functionalities.
#
# ### `__init__`
# - Constructor method for initializing the linked list.
#
# ### `append(value)`
# - Appends a new node with the given `value` to the end of the linked list.
#
# ### `insert_at_beginning(value)`
# - Inserts a new node with the given `value` at the beginning of the linked list.
#
# ### `insert_at_index(value, index)`
# - Inserts a new node with the given `value` at the specified index in the linked list.
#
# ### `insert_at_end(value)`
# - Inserts a new node with the given `value` at the end of the linked list.
#
# ### `update_node(value, index)`
# - Updates the value of a node at the specified index.
#
# ### `remove_first_node()`
# - Removes the first node from the linked list.
#
# ### `remove_last_node()`
# - Removes the last node from the linked list.
#
# ### `remove_at_index(index)`
# - Removes a node at the specified index.
#
# ### `remove_node(value)`
# - Removes the node with the specified value.
#
# ### `size_of_linked_list()`
# - Returns the size of the linked list.
#
# ### `display()`
# - Displays the linked list.
#
# ## Visualization (Optional)
# If you wish to include the visualization part:
#
# ### `visualize()`
# - Visualizes the linked list using NetworkX and Matplotlib.
#
# ## Main Function
# The `main()` function demonstrates the usage of the `MyLinkedList` class by creating a linked list and displaying its contents.

# %%
import networkx as nx
import matplotlib.pyplot as plt


class MyLinkedList:
    class Node:
        def __init__(self, value=None, next_node=None):
            self.value = value
            self.next_node = next_node

    def __init__(self):
        self.head = None

    class LinkedListIterator:
        def __init__(self, node):
            self.current = node

        def __next__(self):
            if self.current is not None:
                current_node = self.current
                self.current = self.current.next_node
                return current_node.value
            else:
                raise StopIteration

    def __iter__(self):
        return self.LinkedListIterator(self.head)

    def append(self, value):
        new_node = self.Node(value)
        if self.head is None:
            self.head = new_node
        else:
            current_node = self.head
            while current_node.next_node is not None:
                current_node = current_node.next_node
            current_node.next_node = new_node

    def insert_at_beginning(self, value):
        new_node = self.Node(value)
        if self.head is None:
            self.head = new_node
        else:
            new_node.next_node = self.head
            self.head = new_node

    def insert_at_index(self, value, index):
        new_node = self.Node(value)
        current_node = self.head
        position = 0
        if position == index:
            self.insert_at_beginning(value)
        else:
            while current_node is not None and position + 1 != index:
                position = position + 1
                current_node = current_node.next_node

            if current_node is not None:
                new_node.next_node = current_node.next_node
                current_node.next_node = new_node
            else:
                print("Index not present")

    def insert_at_end(self, value):
        new_node = self.Node(value)
        if self.head is None:
            self.head = new_node
        else:
            current_node = self.head
            while current_node.next_node:
                current_node = current_node.next_node
            current_node.next_node = new_node

    def update_node(self, value, index):
        current_node = self.head
        position = 0
        while current_node is not None and position != index:
            position = position + 1
            current_node = current_node.next_node

        if current_node is not None:
            current_node.value = value
        else:
            print("Index not present")

    def remove_first_node(self):
        if self.head is not None:
            self.head = self.head.next_node

    def remove_last_node(self):
        if self.head is not None:
            current_node = self.head
            while current_node.next_node and current_node.next_node.next_node:
                current_node = current_node.next_node
            current_node.next_node = None

    def remove_at_index(self, index):
        if self.head is not None:
            current_node = self.head
            position = 0
            if position == index:
                self.remove_first_node()
            else:
                while current_node is not None and position + 1 != index:
                    position = position + 1
                    current_node = current_node.next_node

                if current_node is not None:
                    current_node.next_node = current_node.next_node.next_node
                else:
                    print("Index not present")

    def remove_node(self, value):
        current_node = self.head
        while current_node is not None and current_node.next_node and current_node.next_node.value != value:
            current_node = current_node.next_node

        if current_node is not None and current_node.next_node:
            current_node.next_node = current_node.next_node.next_node

    def size_of_linked_list(self):
        size = 0
        current_node = self.head
        while current_node:
            size = size + 1
            current_node = current_node.next_node
        return size

    def display(self):
        current_node = self.head
        while current_node is not None:
            print(current_node.value)
            current_node = current_node.next_node
        print()

    def visualize_list(self):
        G = nx.DiGraph()

        current_node = self.head
        while current_node and current_node.next_node:
            G.add_node(current_node.value)
            G.add_node(current_node.next_node.value)
            G.add_edge(current_node.value, current_node.next_node.value)

            current_node = current_node.next_node

        pos = nx.spring_layout(G)
        nx.draw(G, pos, with_labels=True, font_weight='bold', node_size=700, node_color='skyblue', alpha=0.7, arrowsize=20)
        plt.title("Linked List")
        plt.show()

# %%
my_linked_list = MyLinkedList()

my_linked_list.append(10)
my_linked_list.append(20)
my_linked_list.append(30)
my_linked_list.visualize_list()

# %%
my_linked_list.insert_at_beginning(5)
my_linked_list.visualize_list()

# %%
my_linked_list.insert_at_index(15, 2)
my_linked_list.visualize_list()

# %%
my_linked_list.insert_at_end(40)
my_linked_list.visualize_list()

# %%
my_linked_list.update_node(25, 1)
my_linked_list.visualize_list()

# %%
my_linked_list.remove_first_node()
my_linked_list.visualize_list()

# %%
my_linked_list.remove_last_node()
my_linked_list.visualize_list()

# %%
my_linked_list.remove_at_index(2)
my_linked_list.visualize_list()

# %%
my_linked_list.remove_node(30)
my_linked_list.visualize_list()

# %%
size = my_linked_list.size_of_linked_list()
print("Size of the linked list:", size)
# Out:
# Size of the linked list: 2

# %% [markdown]
# # Time and Space Complexity Analysis for MyLinkedList Class
#
# ## `__init__(self)`
# **Time Complexity:** O(1)
#
# Initializing an empty linked list is a constant-time operation as it only involves setting the head reference to None.
#
# **Space Complexity:** O(1)
#
# The space complexity is constant because it only creates a reference to the head node.
#
# ## `append(self, value)`
# **Time Complexity:** O(n)
#
# Appending a value to the end of the linked list requires traversing the entire list to find the last node. In the worst case, it takes linear time.
#
# **Space Complexity:** O(1)
#
# Only one new node is created, so the space complexity is constant.
#
# ## `insert_at_beginning(self, value)`
# **Time Complexity:** O(1)
#
# Inserting a value at the beginning involves creating a new node and updating the head reference, which is a constant-time operation.
#
# **Space Complexity:** O(1)
#
# The space complexity is constant as it only creates one new node.
#
# ## `insert_at_index(self, value, index)`
# **Time Complexity:** O(n)
#
# Inserting a value at a specific index may require traversing the list until reaching the desired position. In the worst case, it takes linear time.
#
# **Space Complexity:** O(1)
#
# It creates only one new node, so the space complexity is constant.
#
# ## `insert_at_end(self, value)`
# **Time Complexity:** O(n)
#
# Inserting a value at the end of the linked list requires traversing the entire list to find the last node. In the worst case, it takes linear time.
#
# **Space Complexity:** O(1)
#
# Only one new node is created, so the space complexity is constant.
#
# ## `update_node(self, value, index)`
# **Time Complexity:** O(n)
#
# Updating a node at a specific index requires traversing the list until reaching the desired position. In the worst case, it takes linear time.
#
# **Space Complexity:** O(1)
#
# No additional data structures are created, so the space complexity is constant.
#
# ## `remove_first_node(self)`
# **Time Complexity:** O(1)
#
# Removing the first node involves updating the head reference, which is a constant-time operation.
#
# **Space Complexity:** O(1)
#
# No additional data structures are created, so the space complexity is constant.
#
# ## `remove_last_node(self)`
# **Time Complexity:** O(n)
#
# Removing the last node may require traversing the entire list to find the second-to-last node. In the worst case, it takes linear time.
#
# **Space Complexity:** O(1)
#
# No additional data structures are created, so the space complexity is constant.
#
# ## `remove_at_index(self, index)`
# **Time Complexity:** O(n)
#
# Removing a node at a specific index may require traversing the list until reaching the desired position. In the worst case, it takes linear time.
#
# **Space Complexity:** O(1)
#
# No additional data structures are created, so the space complexity is constant.
#
# ## `remove_node(self, value)`
# **Time Complexity:** O(n)
#
# Removing a node with a specific value may require traversing the list to find the target node. In the worst case, it takes linear time.
#
# **Space Complexity:** O(1)
#
# No additional data structures are created, so the space complexity is constant.
#
# ## `size_of_linked_list(self)`
# **Time Complexity:** O(n)
#
# Calculating the size of the linked list requires traversing the entire list to count the nodes, resulting in linear time complexity.
#
# **Space Complexity:** O(1)
